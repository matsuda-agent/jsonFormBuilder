# %%
import pandas as pd

# %%
applicant_data = pd.read_csv('applicant_details_rows.csv')

applicant_data
# Out:
#                                       id  loan_application_id  \
# 0   ad06365a-022b-4116-a45f-3e70359edc38                   38
# 1   dee15447-1fce-4587-9cb1-493f99214ad4                   38
# 2   73074f6d-5f14-4076-83ba-55a413f4ab5f                   38
# 3   dc594326-00c3-4866-bc1c-3f37861e06ea                   38
# 4   5647a229-59aa-4ba9-bfac-34c6c6f6b2e2                   38
# 5   4456ae6b-a29f-4f90-a5a8-5195ccb24607                   38
# 6   219d0d5c-e890-4662-8b29-1a6e21f90017                   38
# 7   71466a48-7740-47b7-b1ff-f596edda907b                   38
# 8   815abe2e-45f2-4226-b998-450aa0c61e23                   38
# 9   52d513cf-4eee-42d7-9461-9dae80f4b009                   38
# 10  8fc88753-b02e-4402-bb11-9568d11ae843                   38
# 11  ab46d90b-0435-47c9-a61b-26cecf181c05                   38
#
#                             applicant_id  applicant_loan_application_id  \
# 0   fea16eac-f236-4663-b3e4-cc80ebaae19b                             52
# ...

# %%
# convert
applicant_data.to_dict('records')
# Out:
# [{'id': 'ad06365a-022b-4116-a45f-3e70359edc38',
#   'loan_application_id': 38,
#   'applicant_id': 'fea16eac-f236-4663-b3e4-cc80ebaae19b',
#   'applicant_loan_application_id': 52,
#   'field_name': 'martial_status',
#   'field_value': nan,
#   'field_type': 'select',
#   'title': 'Martial Status',
#   'description': 'Enter your Martial Status',
#   'is_required': True,
#   'validation_schema': nan,
#   'status': 'pending',
#   'options': '{"options": [{"label": "Single", "value": "single"}, {"label": "Married", "value": "married"}, {"label": "Divorced", "value": "divorced"}]}',
#   'dependant_on': nan,
#   'created_at': '2024-09-05 20:25:38.67597+00',
#   'updated_at': '2024-09-05 20:25:38.675982+00',
#   'form_name': 'Applicants Information',
#   'field_order': 4,
#   'disabled': False},
#  {'id': 'dee15447-1fce-4587-9cb1-493f99214ad4',
#   'loan_application_id': 38,
#   'applicant_id': 'fea16eac-f236-4663-b3e4-cc80ebaae19b',
#   'applicant_loan_application_id': 52,
# ...

# %%
import json 

with open('applicant_details_rows.json', 'w') as f:
    json.dump(applicant_data.to_dict('records'), f)
